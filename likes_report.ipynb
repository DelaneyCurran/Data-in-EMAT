# %% [markdown]
# # Likes report
# ## Delaney Curran
# ### 09/08/2022

# %% [markdown]
# Hypothesis (part 5)
#
# If a post is liked, then it is more likely to be an 'influencer' then someone you know personally. If a post is commented on, then it is more likely a someone you know personally.
# A file that would be useful in testing this hypothesis would be my "post_comments.json"
#
# A. I Can tell based off of my data I collected and my own personal behavior on Instagram That I like more "influencer" post and I comment more on people I know personally posts.
#
# B. In order to test this it would Be helpful To collect data from multiple people rather than just my own personal data to compare and contrast activity on Instagram.

# %%
import pandas as pd
import json

# %% [markdown]
# Part 1.

# %%
with open(r"/Users/delaneycurran/Desktop/Business analytics II/EMAT/d_curran_20220907/likes/liked_posts.json") as j:
    IG_likes = json.load(j)

# %% [markdown]
# Part 2.

# %%
IG_likes
# Out:
# {'likes_media_likes': [{'title': 'niallfacts',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/XbZK4qsCqs/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1364558396}]},
#   {'title': 'niallfacts',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/XbcuSPsCvS/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1364558370}]},
#   {'title': 'fashionware',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Xa_smfx3gX/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1364522578}]},
#   {'title': 'niallfacts',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/XbGNTtMCui/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1364522149}]},
#   {'title': 'you_got_memed',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Xa3k4ATWOC/',
#      'value': 'ð\x9f\x91\x8d',
# ...

# %% [markdown]
# A. Who collected this data?
#
# I think that I collected this data. Yes I downloaded it but I also collected it. This is my own personal Instagram showing everything I've liked in the 12 years I've had it. I was the one who liked the post. Without me liking and interacting with post there would be no data at all. However I also think that Instagram collected this data. They collected this data in the way of storing it. Without Instagram keeping a file of all my liked post I'll would not be able to be looking at it today. So I think that I collected the data for Instagram to store the data.

# %%
test1 = pd.DataFrame(IG_likes['likes_media_likes'])

# %%
test1
# Out:
#                       title media_list_data  \
# 0                niallfacts              []
# 1                niallfacts              []
# 2               fashionware              []
# 3                niallfacts              []
# 4             you_got_memed              []
# ...                     ...             ...
# 53115  peace.love.behr.down              []
# 53116         chrissyteigen              []
# 53117             nenaevans              []
# 53118        oceanastrachan              []
# 53119          thedzignshop              []
#
#                                         string_list_data
# 0      [{'href': 'https://www.instagram.com/p/XbZK4qs...
# 1      [{'href': 'https://www.instagram.com/p/XbcuSPs...
# 2      [{'href': 'https://www.instagram.com/p/Xa_smfx...
# 3      [{'href': 'https://www.instagram.com/p/XbGNTtM...
# 4      [{'href': 'https://www.instagram.com/p/Xa3k4AT...
# ...                                                  ...
# ...

# %% [markdown]
# B. why was this data collected?
#
# I think that this data was collected because Instagram is using it to understand what kind of post every user interacts with the most. Instagram sells our data to advertisers and feeds us ads of products that we are likely to buy. Instagram is a business and they need to make money somehow. Personally I'll think that this level of data that is collected on everyone can be intrusive and kind of scary. But I also don't think I will ever stop using Instagram so I guess we are stuck in this cycle

# %%
test1['string_list_data'][0]
# Out:
# [{'href': 'https://www.instagram.com/p/XbZK4qsCqs/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1364558396}]

# %%
test1['string_list_data'][0][0]
# Out:
# {'href': 'https://www.instagram.com/p/XbZK4qsCqs/',
#  'value': 'ð\x9f\x91\x8d',
#  'timestamp': 1364558396}

# %%
test1['string_list_data'][0][0]['value']
# Out:
# 'ð\x9f\x91\x8d'

# %%
value = [x[0]['value'] for x in test1['string_list_data']]

# %%
value
# Out:
# ['ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
#  'ð\x9f\x91\x8d',
# ...

# %%
test1['string_list_data'][0]
# Out:
# [{'href': 'https://www.instagram.com/p/XbZK4qsCqs/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1364558396}]

# %%
test1['string_list_data'][0][0]
# Out:
# {'href': 'https://www.instagram.com/p/XbZK4qsCqs/',
#  'value': 'ð\x9f\x91\x8d',
#  'timestamp': 1364558396}

# %%
test1['string_list_data'][0][0]['timestamp']
# Out:
# 1364558396

# %%
timestamp = [x[0]['timestamp'] for x in test1['string_list_data']]

# %%
timestamp
# Out:
# [1364558396,
#  1364558370,
#  1364522578,
#  1364522149,
#  1364519471,
#  1364519439,
#  1364519363,
#  1364519351,
#  1364519284,
#  1364513877,
#  1364513566,
#  1364499454,
#  1364499445,
#  1364489937,
#  1364489459,
#  1364484607,
#  1364482827,
#  1364475139,
#  1364474719,
#  1364436745,
#  1364436212,
#  1364433237,
#  1364432326,
#  1364432231,
#  1364431288,
#  1364431184,
#  1364414552,
#  1364413262,
#  1364413211,
#  1364413157,
#  1364412766,
#  1364411670,
#  1364405105,
#  1364405046,
#  1364404925,
#  1364404368,
#  1364404253,
#  1364403180,
#  1364398113,
#  1364396026,
#  1364396020,
#  1364396005,
#  1364395993,
#  1364395985,
#  1364395979,
#  1364395952,
#  1364395946,
#  1364385154,
#  1364349566,
#  1364345790,
#  1364345507,
#  1364345407,
#  1364344774,
#  1364344766,
#  1364341561,
#  1364341358,
#  1364341278,
#  1364341217,
#  1364341186,
#  1364341106,
#  1364338761,
#  1364338750,
#  1364337536,
#  1364324963,
#  1364320850,
#  1364304489,
# ...

# %%
test1['value'] = value

# %%
test1['timestamp'] = timestamp

# %%
test1
# Out:
#                       title media_list_data  \
# 0                niallfacts              []
# 1                niallfacts              []
# 2               fashionware              []
# 3                niallfacts              []
# 4             you_got_memed              []
# ...                     ...             ...
# 53115  peace.love.behr.down              []
# 53116         chrissyteigen              []
# 53117             nenaevans              []
# 53118        oceanastrachan              []
# 53119          thedzignshop              []
#
#                                         string_list_data value   timestamp
# 0      [{'href': 'https://www.instagram.com/p/XbZK4qs...  ð  1364558396
# 1      [{'href': 'https://www.instagram.com/p/XbcuSPs...  ð  1364558370
# 2      [{'href': 'https://www.instagram.com/p/Xa_smfx...  ð  1364522578
# 3      [{'href': 'https://www.instagram.com/p/XbGNTtM...  ð  1364522149
# ...

# %% [markdown]
# Part 4.

# %%
test1.groupby('title').count().sort_values('title',ascending=False)
# Out:
#                   media_list_data  string_list_data  value  timestamp
# title
# zyrastyle                       1                 1      1          1
# zupless                         4                 4      4          4
# zu.tara                         1                 1      1          1
# ztafraternity                   1                 1      1          1
# zozoroe                        68                68     68         68
# ...                           ...               ...    ...        ...
# 101blackplatinum                1                 1      1          1
# 100laurencandy                  1                 1      1          1
# 100.west                        1                 1      1          1
# 0chills                         1                 1      1          1
# 00halianderson11               11                11     11         11
#
# [9576 rows x 4 columns]

# %%
test1.groupby('title').count().sort_values('value',ascending=False)
# Out:
#                           media_list_data  string_list_data  value  timestamp
# title
# truth_jokes                          1042              1042   1042       1042
# sarahs_day                            583               583    583        583
# theprogressivists                     531               531    531        531
# feminist                              505               505    505        505
# meganbunnell13                        419               419    419        419
# ...                                   ...               ...    ...        ...
# kingtoks                                1                 1      1          1
# kingsamberg                             1                 1      1          1
# kings_slowpitch_softball                1                 1      1          1
# kingofmystyle                           1                 1      1          1
# zyrastyle                               1                 1      1          1
#
# [9576 rows x 4 columns]

# %% [markdown]
# C. In what way is this data reliable?
#
# D. in what way is this data unreliable?
#
# I think this data is reliable in counting the number of posts by each person that I have liked And the exact time I liked the post. These are hard numbers that I don't think can be disputed. We can see based on the data that I liked truth_jokes post more than anyone else. However this data is unreliable now. Truth_jokes is an account that I've thought was hilarious when I first got Instagram when I was when I was 11. You would think  that based on the amount of post I like I would be interacting with them on a daily basis however I don't think that I have even thought about their post in 10 years. I also think that this data can be unreliable because sometimes I will accidentally like post that I did not I intend on liking. In the opposite way there are post that I want to like that don't go through for whatever reason.

# %% [markdown]
# Conclusion:
#
# Based on the data I collected and I the test I have run have can say that I spend a lot of time on Instagram. I mostly interact with "influencer" then people I know in real life. It is interesting to see how many posts I have liked that I can't even recall the account. I realize that I have in this. There is so  many ways I can think of organizing and transforming this data that I just simply don't have the skills for yet. Once I acquire more skills I think it would be interesting to look at the time I have spent on the app, the time of day I spend the most, the day of the week, the time of the year. I am very interested to see how much more I can do in transforming raw data.
